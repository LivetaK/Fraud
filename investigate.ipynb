# %%
import pandas as pd

credit_card_data = pd.read_parquet('data/credit_card_transactions-ibm_v2.parquet')
sd254_cards = pd.read_parquet('data/sd254_cards.parquet')
sd254_users = pd.read_parquet('data/sd254_users.parquet')
user_0_credit_card_data = pd.read_parquet('data/User0_credit_card_transactions.parquet')

# %%
display(credit_card_data)
display(sd254_cards)
display(sd254_users)
display(user_0_credit_card_data)
# Out:
#           User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 0            0     0  2002      9    1  06:21  $134.09  Swipe Transaction
# 1            0     0  2002      9    1  06:42   $38.48  Swipe Transaction
# 2            0     0  2002      9    2  06:22  $120.34  Swipe Transaction
# 3            0     0  2002      9    2  17:45  $128.95  Swipe Transaction
# 4            0     0  2002      9    3  06:23  $104.71  Swipe Transaction
# ...        ...   ...   ...    ...  ...    ...      ...                ...
# 24386895  1999     1  2020      2   27  22:23  $-54.00   Chip Transaction
# 24386896  1999     1  2020      2   27  22:24   $54.00   Chip Transaction
# 24386897  1999     1  2020      2   28  07:43   $59.15   Chip Transaction
# 24386898  1999     1  2020      2   28  20:10   $43.12   Chip Transaction
# 24386899  1999     1  2020      2   28  23:10   $45.13   Chip Transaction
#
#                 Merchant Name  Merchant City Merchant State      Zip   MCC  \
# ...

# %%
print("credit_card_transactions: ", credit_card_data.columns)
print("sd254_cards: ", sd254_cards.columns)
print("sd254_users: ", sd254_users.columns)
print("User0_credit_card_transactions: ", user_0_credit_card_data.columns)
# Out:
# credit_card_transactions:  Index(['User', 'Card', 'Year', 'Month', 'Day', 'Time', 'Amount', 'Use Chip',
#        'Merchant Name', 'Merchant City', 'Merchant State', 'Zip', 'MCC',
#        'Errors?', 'Is Fraud?'],
#       dtype='object')
# sd254_cards:  Index(['User', 'CARD INDEX', 'Card Brand', 'Card Type', 'Card Number',
#        'Expires', 'CVV', 'Has Chip', 'Cards Issued', 'Credit Limit',
#        'Acct Open Date', 'Year PIN last Changed', 'Card on Dark Web'],
#       dtype='object')
# sd254_users:  Index(['Person', 'Current Age', 'Retirement Age', 'Birth Year', 'Birth Month',
#        'Gender', 'Address', 'Apartment', 'City', 'State', 'Zipcode',
#        'Latitude', 'Longitude', 'Per Capita Income - Zipcode',
#        'Yearly Income - Person', 'Total Debt', 'FICO Score',
#        'Num Credit Cards'],
#       dtype='object')
# User0_credit_card_transactions:  Index(['User', 'Card', 'Year', 'Month', 'Day', 'Time', 'Amount', 'Use Chip',
# ...

# %%
print(",\n".join(f'"{col}"' for col in credit_card_data.columns))
# Out:
# "User",
# "Card",
# "Year",
# "Month",
# "Day",
# "Time",
# "Amount",
# "Use Chip",
# "Merchant Name",
# "Merchant City",
# "Merchant State",
# "Zip",
# "MCC",
# "Errors?",
# "Is Fraud?"
